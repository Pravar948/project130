# %% [markdown]
# <a href="https://colab.research.google.com/github/Pravar948/project130/blob/main/project130.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-48946e5d-aba7-4023-8b13-651716e53e3b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-48946e5d-aba7-4023-8b13-651716e53e3b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import csv
df = pd.read_csv('total_stars.csv')
df.head()
# Out:
#    Unnamed: 0       Star_name     Distance Mass Radius Luminosity  Unnamed: 6  \
# 0           0             Sun  0.000015813    1      1          1         NaN
# 1           1          Sirius       0008.6  2.1   1.71       25.4         NaN
# 2           2         Canopus         0310   15     71     13,500         NaN
# 3           3  Alpha Centauri       0004.4  1.1    1.2          2         NaN
# 4           4        Arcturus         0037  1.1     26        170         NaN
#
#    Star_name.1  Distance.1  Mass.1  Radius.1
# 0          NaN         NaN     NaN       NaN
# 1          NaN         NaN     NaN       NaN
# 2          NaN         NaN     NaN       NaN
# 3          NaN         NaN     NaN       NaN
# 4          NaN         NaN     NaN       NaN

# %%
df.drop(['Unnamed: 0','Unnamed: 6', 'Star_name.1', 'Distance.1', 'Mass.1', 'Radius.1','Luminosity'],axis=1,inplace=True)

# %%
df.head()
# Out:
#         Star_name     Distance Mass Radius
# 0             Sun  0.000015813    1      1
# 1          Sirius       0008.6  2.1   1.71
# 2         Canopus         0310   15     71
# 3  Alpha Centauri       0004.4  1.1    1.2
# 4        Arcturus         0037  1.1     26

# %%
final_data = df.dropna()
final_data.reset_index(drop = True, inplace = True)
final_data
# Out:
#                   Star_name     Distance                  Mass  \
# 0                       Sun  0.000015813                     1
# 1                    Sirius       0008.6                   2.1
# 2                   Canopus         0310                    15
# 3            Alpha Centauri       0004.4                   1.1
# 4                  Arcturus         0037                   1.1
# ..                      ...          ...                   ...
# 250  2MASSI J2356547-155310         74.0            0.07636704
# 251          WISE 0410+1502         20.0           0.005727528
# 252         WISE 0458+6434A         35.9  0.014318820000000001
# 253         WISE 0458+6434B         35.9            0.00954588
# 254          WISE 1405+5534         25.3  0.028637640000000002
#
#                   Radius
# 0                      1
# 1                   1.71
# 2                     71
# 3                    1.2
# 4                     26
# ..                   ...
# ...

# %%
final_data.to_csv('final_data.csv')
